# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import numpy
import os
import gzip
import collections

from six.moves import urllib

import tensorflow as tf 
from tensorflow.python.platform.default import _gfile as gfile

# below modules are for plotting

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %matplotlib inline

# %%
def _read32(bytestream):
  dt = numpy.dtype(numpy.uint32).newbyteorder('>')
  return numpy.frombuffer(bytestream.read(4), dtype=dt)[0]

# %%
def extract_images(filename):
  """Extract the images into a 4D uint8 numpy array [index, y, x, depth]."""
  print('Extracting', filename)
  with gfile.Open(filename, 'rb') as f, gzip.GzipFile(fileobj=f) as bytestream:
    magic = _read32(bytestream)
#    if magic != 2051:
#      raise ValueError(
#          'Invalid magic number %d in MNIST image file: %s' %
#          (magic, filename))
    num_images = _read32(bytestream)
    print('num_images : ',num_images)
    rows = _read32(bytestream)
    print('rows : ',rows)
    cols = _read32(bytestream)
    print('cols : ',cols)
    buf = bytestream.read(rows * cols * num_images)
    data = numpy.frombuffer(buf, dtype=numpy.uint8)
    data = data.reshape(1, rows, cols, 1)
    return data

# %%
extract_images("data/san_francisco.jpg.gz")
# Out:
# Extracting data/san_francisco.jpg.gz
# num_images :  1067590
# rows :  1229324289
# cols i:  33554433
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:16: RuntimeWarning: overflow encountered in uint_scalars
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-900efdc36591> in <module>()
# ----> 1 extract_images("data/san_francisco.jpg.gz")
#
# <ipython-input-29-3aaf983a072d> in extract_images(filename)
#      16     buf = bytestream.read(rows * cols * num_images)
#      17     data = numpy.frombuffer(buf, dtype=numpy.uint8)
# ---> 18     data = data.reshape(1, rows, cols, 1)
#      19     return data
#
# ValueError: total size of new array must be unchanged

# %%
image = mpimg.imread("data/san_francisco.png")
plt.imshow(image)
plt.show()

print(image.shape)
print(image.shape[0])
print(image.shape[1])

IMAGE_HEIGTH = image.shape[0]
IMAGE_WIDTH = image.shape[1]
PIXEL_DEPTH = 255
# Out:
# (331, 550, 3)
# 331
# 550

# %%
def extract_data(filename, num_images):
  """Extract the images into a 4D tensor [image index, y, x, channels].
  Values are rescaled from [0, 255] down to [-0.5, 0.5].
  """
  print('Extracting', filename)
  with gzip.open(filename) as bytestream:
    
    for field in ['magic number', 'image count', 'rows', 'columns']:
    # struct.unpack reads the binary data provided by f.read.
    # The format string '>i' decodes a big-endian integer, which
    # is the encoding of the data.
        print(field, struct.unpack('>i', bytestream.read(4))[0])
    
    bytestream.read(16)
       
    buf = bytestream.read(IMAGE_WIDTH * IMAGE_HEIGTH * num_images)
    data1 = np.frombuffer(buf, dtype=np.uint8).astype(np.float32)
    data2 = (data1 - (PIXEL_DEPTH / 2.0)) / PIXEL_DEPTH
    data3 = ''
#    data3 = data2.reshape(num_images, IMAGE_WIDTH, IMAGE_HEIGTH, 1)
    return data1,data2,data3

# %%
data1,data2,data3 = extract_data('data/san_francisco.jpg.gz',1)

print(data1[:5])
print(len(data1))
print(data2[:5])
print(data1.shape)
print(data2.shape)

#print(data1.shape)
#print(data2.shape)
#print(data3.shape)
#print(data2)
# Out:
# Extracting data/san_francisco.jpg.gz
# magic number -2555936
# image count 1067590
# rows 1229324289
# columns 33554433
# [ 7.  7.  7.  9.  9.]
# 36198
# [-0.47254902 -0.47254902 -0.47254902 -0.46470588 -0.46470588]
# (36198,)
# (36198,)

# %%
conv1_weights = tf.Variable(tf.truncated_normal([1, 1, 2, 4],  
                          stddev=0.1,
                          seed=None))


conv2_weights = tf.Variable(tf.truncated_normal([1, 2, 1, 1],  
                          stddev=0.1,
                          seed=None))


conv3_weights = tf.Variable(tf.truncated_normal([2, 1, 1, 1],  
                          stddev=0.1,
                          seed=None))

with tf.Session() as sess:
    
    tf.initialize_all_variables().run()
    
    test1 = conv1_weights.eval()
    test2 = conv2_weights.eval()
    test3 = conv3_weights.eval()
    
    print('2*1*1*1 weight matrix : \n\n  ',test3)  
    print('')
    
    print('1*2*1*1 weight matrix : \n\n  ',test2)    
    print('')
    
    print('1*1*2*4 weight matrix : \n\n :', test1) 
    print('')
# Out:
# 2*1*1*1 weight matrix :
#
#    [[[[-0.02657349]]]
#
#
#  [[[-0.09143468]]]]
#
# 1*2*1*1 weight matrix :
#
#    [[[[ 0.04762639]]
#
#   [[-0.07135923]]]]
#
# 1*1*2*4 weight matrix :
#
#  : [[[[-0.04902065 -0.07074369  0.050292    0.08372145]
#    [-0.09106921 -0.05739514 -0.07346068  0.12867919]]]]
