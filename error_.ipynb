# %%
import commands
import platform

print("\nSystem Info --------\n")

print(platform.machine())
print(platform.system())


print("\nAnaconda Info --------\n")

print commands.getstatusoutput('conda -V')


print("\nPackage Info --------\n")

packages = commands.getstatusoutput('conda list | grep -v "r-"')[1]

print(packages)
# Out:
# System Info --------
#
# x86_64
# Linux
#
# Anaconda Info --------
#
# (0, 'conda 4.0.6')
#
# Package Info --------
#
# # packages in environment at /home/vagrant/anaconda2/envs/tensorflow:
# #
# amqp                      1.4.8                     <pip>
# anaconda-client           1.4.0                    py27_0    defaults
# anaconda-nb-extensions    1.0.0                    py27_0    anaconda-nb-extensions
# anyjson                   0.3.3                     <pip>
# babel                     2.0                       <pip>
# backports                 1.0                      py27_0    defaults
# backports-abc             0.4                       <pip>
# backports.shutil-get-terminal-size 1.0.0                     <pip>
# backports.ssl-match-hostname 3.5.0.1                   <pip>
# backports_abc             0.4                      py27_0    defaults
# beaker                    1.7.0                     <pip>
# bioblend                  0.7.0                     <pip>
# ...
